# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("white")
sns.set_context("poster")

plt.rcParams["figure.figsize"] = (20,15)
plt.rcParams['image.cmap'] = 'jet'

# %% [markdown]
# # Aim 1: Mismatch Compression
# ## Multimodal Recordings: Research-Grade DAQ
#
# In this notebook we'll take a look at the three different modalities of neural recordings using in my dissertation.
#
#
# ## Setup

# %%
from dbspace.utils.io.brPY.brpylib import NsxFile, brpylib_ver
from dbspace.viz.MM.intraop import blackrock_plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/multimodal_check/A1_MM_OR.ipynb Cell 2' in <cell line: 12>()
#      <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/multimodal_check/A1_MM_OR.ipynb#ch0000001?line=9'>10</a> import sys
#      <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/multimodal_check/A1_MM_OR.ipynb#ch0000001?line=10'>11</a> sys.path.append('/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/or_reset/')
# ---> <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/multimodal_check/A1_MM_OR.ipynb#ch0000001?line=11'>12</a> from brPY.brpylib import NsxFile, brpylib_ver
#      <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/multimodal_check/A1_MM_OR.ipynb#ch0000001?line=12'>13</a> plt.rcParams['image.cmap'] = 'jet'
#
# ModuleNotFoundError: No module named 'brPY'

# %%
#datafile = '/home/virati/MDD_Data/OR/DBS906/20150727-174713/20150727-174713-001.ns2'
#datafile = '/home/virati/MDD_Data/OR/DBS906/20150727-181004/20150727-181004-001.ns2'

# %% [markdown]
# ## Research-grade
# The best recordings we have are from the Intraoperative-BlackRock DAQ.
#
#
# ### DBS905 - 08/2015

# %%
blackrock_plot(pt='905',zoom=False,subtr_baseline=True,domain='T')
# Out:
# 20150831-164204-002.ns2 opened
# 500.0
#
# 20150831-164204-002.ns2 closed

# %%
blackrock_plot(pt='905',zoom=False,subtr_baseline=True)
# Out:
# 20150831-164204-002.ns2 opened
# 500.0
# /tmp/ipykernel_558118/604286973.py:44: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(T,F,10*np.log10(SG))
# /tmp/ipykernel_558118/604286973.py:44: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(T,F,10*np.log10(SG))
# 20150831-164204-002.ns2 closed

# %% [markdown]
# Looking at the time-domain, the periods with active stimulation are very obvious.
# At first glance you may lose hope; how could we ever see what the brain is doing since the stim is doing so much?
#
# Lucky for us, there aren't over signs that we're saturating.
# While gain compression appears to be present, the broad slope flattening we expect from gain compression is not very present (See XLTek).

# %% [markdown]
# ### DBS906 - 07/2015

# %%
blackrock_plot(pt='906',zoom=False,subtr_baseline=True)
# Out:
# *** File given does exist, try again ***
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_558118/2530785783.py in <module>
# ----> 1 blackrock_plot(pt='906',zoom=False,subtr_baseline=True)
#
# /tmp/ipykernel_558118/604286973.py in blackrock_plot(pt, zoom, subtr_baseline, domain)
#      18         plotch = 30
#      19
# ---> 20     nsx_file = NsxFile(datafile)
#      21
#      22     # Extract data - note: data will be returned based on *SORTED* elec_ids, see cont_data['elec_ids']
#
# ~/Dropbox/projects/Research/MDD-DBS/Ephys/or_reset/brPY/brpylib.py in __init__(self, datafile)
#     725
#     726         # Run openfilecheck and open the file passed or allow user to browse to one
# --> 727         self.datafile = openfilecheck('rb', file_name=self.datafile, file_ext='.ns*', file_type='Blackrock NSx Files')
#     728
#     729         # Determine File ID to determine if File Spec 2.1
#
# ~/Dropbox/projects/Research/MDD-DBS/Ephys/or_reset/brPY/brMiscFxns.py in openfilecheck(open_mode, file_name, file_ext, file_type)
#      37
#      38             # Ask user to specify a file path or browse
# ---> 39             file_name = input("Enter complete " + file_ext + " file path or hit enter to browse: ")
#      40
#      41             if not file_name:
#
# ~/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1042                 "raw_input was called, but this frontend does not support input requests."
#    1043             )
# -> 1044         return self._input_request(
#    1045             str(prompt),
#    1046             self._parent_ident["shell"],
#
# ~/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1087             except KeyboardInterrupt:
#    1088                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1089                 raise KeyboardInterrupt("Interrupted by user") from None
#    1090             except Exception:
#    1091                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
