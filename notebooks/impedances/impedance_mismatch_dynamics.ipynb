# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20,15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py:595, in RcParams.__setitem__(self, key, val)
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=593'>594</a> try:
# --> <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=594'>595</a>     cval = self.validate[key](val)
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=595'>596</a> except ValueError as ve:
#
# KeyError: 'figsize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/impedances/impedance_mismatch_dynamics.ipynb Cell 1' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/impedances/impedance_mismatch_dynamics.ipynb#ch0000000?line=0'>1</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/impedances/impedance_mismatch_dynamics.ipynb#ch0000000?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/notebooks/impedances/impedance_mismatch_dynamics.ipynb#ch0000000?line=3'>4</a> plt.rcParams['figsize'] = (20,15)
#
# File ~/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py:600, in RcParams.__setitem__(self, key, val)
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=597'>598</a>     dict.__setitem__(self, key, cval)
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=598'>599</a> except KeyError as err:
# --> <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=599'>600</a>     raise KeyError(
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=600'>601</a>         f"{key} is not a valid rc parameter (see rcParams.keys() for "
#     <a href='file:///home/virati/Dropbox/projects/Research/MDD-DBS/Ephys/mismatch_compression/.venv/lib/python3.8/site-packages/matplotlib/__init__.py?line=601'>602</a>         f"a list of valid parameters)") from err
#
# KeyError: 'figsize is not a valid rc parameter (see rcParams.keys() for a list of valid parameters)'

# %%
from dbspace.signal.dLFP.impedances import Z_class
import matplotlib.pyplot as plt

Z_lib = Z_class()
Z_lib.get_recZs()
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# DBS901
# DBS903
# DBS905
# DBS906
# DBS907
# DBS908
# DBS901
# DBS903
# DBS905
# DBS906
# DBS907
# DBS908

# %%
Z_lib.plot_recZs()

# %%
Z_lib.dynamics_measures()

# %%
Z_lib.impedance_histogram()
# Out:
# Left 1187.5
# Right 1130.0
