# %%
from dbspace.signal.dLFP.impedances import Z_class
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (20,15)

# %%
Z_lib = Z_class(impedance_file_path='/home/vscode/data/Anatomy/CT/Zs_GMs_Es.xlsx', do_pts=["DBS901", "DBS903", "DBS905", "DBS906", "DBS907", "DBS908"])
Z_lib.load_data_from_file()
Z_lib.get_recZs()

# %%
Z_lib.plot_recZs()

# %%
Z_lib.gen_Zdiff().dynamics_measures()

# %%
Z_lib.impedance_histogram()
# Out:
# Left 1187.5
# Right 1130.0
